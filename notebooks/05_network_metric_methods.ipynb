# %% [markdown]
# # Preliminary network-metric methods
#
# Repositories are treated as papers and users as authors. Distances are calculated on the largest connected component; clustering is global transitivity.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))
DATA_PATH = ROOT / "data" / "synthetic_perlmutter_memberships_2020_2026.csv"
OUTPUT_DIR = ROOT / "outputs"
OUTPUT_DIR.mkdir(exist_ok=True)

import pandas as pd
from artifact_utils import load_memberships, network_metrics

# %%
memberships = load_memberships(DATA_PATH)
example = pd.DataFrame([
    network_metrics(memberships, "NERSC (all offices)"),
    network_metrics(memberships[memberships["office"].eq("High Energy Physics")], "HEP"),
])
example.round(3)
# Out:
#                network  total_repos  total_users  mean_repos_per_user  \
# 0  NERSC (all offices)          148         1200                3.381
# 1                  HEP           19          163                2.982
#
#    mean_users_per_repo  mean_collaborators_per_user  \
# 0               27.412                       74.508
# 1               25.579                       65.227
#
#    mean_distance_giant_component  maximum_distance_giant_component  \
# 0                          2.330                                 6
# 1                          1.512                                 3
#
#    global_clustering_coefficient  giant_component_size  \
# 0                          0.659                  1066
# 1                          0.730                   145
#
#    second_largest_component_size
# 0                              5
# 1                              5
